# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/kaggle/input/fortune-global-500-companies-2023-list/fortune_global_500_2023.csv')

# %%
df.head()
# Out:
#                       industry                       company        country  \
# 0          Aerospace & Defense                        Boeing  United States
# 1                     Airlines             American Airlines  United States
# 2                      Apparel                Christian Dior         France
# 3  Banks: Commercial & Savings  Industrial & Commercial Bank          China
# 4                    Beverages          Anheuser-Busch InBev        Belgium
#
#    rank  revenue_m
# 0    64      93392
# 1   260      42207
# 2   208      49221
# 3    26     153021
# 4   170      56444

# %%
df.shape
# Out:
# (55, 5)

# %%
df.isnull().sum()
# Out:
# industry     0
# company      0
# country      0
# rank         0
# revenue_m    0
# dtype: int64

# %%
df.dtypes
# Out:
# industry     object
# company      object
# country      object
# rank          int64
# revenue_m     int64
# dtype: object

# %%
df.describe()
# Out:
#              rank      revenue_m
# count   55.000000      55.000000
# mean   127.618182  115907.218182
# std    122.711117   93641.080036
# min      1.000000   26670.000000
# 25%     21.500000   48672.500000
# 50%     92.000000   79139.000000
# 75%    209.500000  158308.500000
# max    441.000000  500343.000000
